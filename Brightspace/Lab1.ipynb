# %% [markdown]
# ## 0\. Background
#
# *   You have been given an insurance dataset and you have been tasked with predicting claims
# *   You have a sample dataset with an <font color="red">OUTCOME</h1></font> target.  1 means that a claim has been made and 0 means that no claim has been made
#
#
# <font color="red"><h1> This lab submission will account for 10% of your grade</h1></font>
#
# <font color="red"><h1> Submit your working notebook with your name </h1></font>

# %% [markdown]
# ## 1\. Load the Dataset into a Pandas DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Project Directory path 
project_dir = 'drive/MyDrive/UW.8740/Lab1/'

# %%
import pandas as pd
insuarnce = pd.read_csv(project_dir+ 'Car_Insurance_Claim.csv')

# %% [markdown]
# ### 1\.1 Display the top 5 rows and bottom 5 rows of the DataFrame
#
# <font color="red"><h1> <Submit Answer Below [1] - 2 points:</h1></font>

# %% [markdown]
# ## 2\.Data Exploration

# %% [markdown]
# ### 2\.1 Identify the number of missing nulls in columns
#
# <font color="red"><h1>Submit Answer Below [2] - 2 points:</h1></font>

# %% [markdown]
# ## 3\.Pre-process the data

# %% [markdown]
# ### 3\.1 Organize your columns into Catogorical features, numeric features and target variable

# %%
categorical_features = ['AGE', 'GENDER', 'RACE', 'DRIVING_EXPERIENCE', 
                        'EDUCATION', 'INCOME', 'VEHICLE_OWNERSHIP', 
                        'VEHICLE_YEAR', 'MARRIED', 'CHILDREN', 
                        'POSTAL_CODE', 'VEHICLE_TYPE']

numeric_features = ['CREDIT_SCORE', 'ANNUAL_MILEAGE', 'SPEEDING_VIOLATIONS', 
                    'DUIS', 'PAST_ACCIDENTS' ]

target = 'OUTCOME'

# %%
X = insuarnce[numeric_features + categorical_features]
y = insuarnce[target]

# %% [markdown]
# ### 3\.2 Feature Transformation
#
#
# *   One Hot Encoding for Categorical
# *   Impute Numeric columns with missing values (use mean)
#
#
# <font color="red"><h1>Submit Answer Below [3] - 2 points:</h1></font>

# %% [markdown]
# ## 4\. Train Predictive Classification Models
#
# Split your data to (80% Training/20% Testing)
#
# Train at least <font color="red">two</font> different classifiers and report the following:
#
#
# *   Confusion Matrix
# *   Accuracy Score
# *   AUC Score
#
#
#
# <font color="red"><h1>Submit Answer Below [3] - 4 points:</h1></font>
