# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Project Directory path
project_dir = 'drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/'

# %%
import glob

# Using '*' pattern
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*'):
    print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Modelling.xlsx
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Modelling.csv
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Load.ipynb
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Modelling.gsheet
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn_Demo_Predict.ipynb
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Demo-EDA.ipynb

# %%
print(project_dir+'*')
# Out:
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/*

# %%
# Using '*' pattern
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*.csv'):
    print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/UW.8740/Lab 02 - Feature Eng and Model Selection/CustomerChurn/Churn-Modelling.csv

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
churn = pd.read_csv(project_dir+ 'Churn-Modelling.csv')
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # Verify unique values of columns

# %%
uniqueIDcount= churn['CustomerId'].nunique()
uniqueIDcount
# Out:
# 10000

# %%
uniqueIDcount
# Out:
# 10000

# %%
churn['CustomerId'].nunique()
# Out:
# 10000

# %%
x = churn['CustomerId'].unique()
len(x)
# Out:
# 10000

# %%
churn['CustomerId'].unique()
# Out:
# array([15634602, 15647311, 15619304, ..., 15584532, 15682355, 15628319])

# %%
len(churn['CustomerId'].unique())
# Out:
# 10000

# %%
churn['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
churn['Geography'].nunique()
# Out:
# 3

# %%
type(churn)
# Out:
# pandas.core.frame.DataFrame

# %%
len(churn['RowNumber'].unique())
# Out:
# 10000

# %%
churn['RowNumber'].nunique()
# Out:
# 10000

# %% [markdown]
# # Reset DataFrame index

# %%
churn.set_index('RowNumber', inplace=True)
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
type(churn)
# Out:
# pandas.core.frame.DataFrame

# %%
#set the RowNumber (Column zero) as the DataFrame Index
#this replaces the default index created by pandas
#notice we have one less column (14 instead of 15)
churn = pd.read_csv(project_dir+ 'Churn-Modelling.csv', index_col=0)
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %% [markdown]
# # Simple Exporatory Data Analysis (EDA)

# %%
churn.head(7)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
# 6            15574012       Chu          645     Spain    Male   44       8
# 7            15592531  Bartlett          822    France    Male   50       7
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# ...

# %%
churn.tail(10)
# Out:
#            CustomerId      Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 9991         15798964   Nkemakonam          714   Germany    Male   33
# 9992         15769959  Ajuluchukwu          597    France  Female   53
# 9993         15657105  Chukwualuka          726     Spain    Male   36
# 9994         15569266       Rahman          644    France    Male   28
# 9995         15719294         Wood          800    France  Female   29
# 9996         15606229     Obijiaku          771    France    Male   39
# 9997         15569892    Johnstone          516    France    Male   35
# 9998         15584532          Liu          709    France  Female   36
# 9999         15682355    Sabbatini          772   Germany    Male   42
# 10000        15628319       Walker          792    France  Female   28
#
#            Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 9991            3     35K              1          1               0
# ...

# %%
churn.sample(5)
# Out:
#            CustomerId       Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 3863         15726588      Seleznev          653     Spain  Female   36
# 8644         15813660      Forlonge          754     Spain    Male   40
# 1847         15812338  Sopuluchukwu          485     Spain  Female   30
# 5043         15593468       Findlay          850    France  Female   33
# 5167         15694644          Wood          455     Spain  Female   43
#
#            Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 3863            3      0K              2          0               0
# 8644            2    161K              1          0               1
# 1847            7      0K              1          1               0
# 5043            3      0K              2          1               1
# 5167            6      0K              1          1               1
#
#            EstimatedSalary  Exited  Unnamed: 14
# RowNumber
# ...

# %%
churn.sample(5, random_state=9)
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 3645         15626233  Onyekachi          593    France  Female   32       3
# 9185         15716984    Palermo          695     Spain  Female   56       4
# 521          15671256  Macartney          850    France  Female   35       1
# 5686         15811565      Cocci          705     Spain  Female   47       3
# 2402         15751336        Yao          630     Spain    Male   30       3
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 3645           0K              2          1               1        151978.36
# 9185           0K              2          1               0         84644.76
# 521          212K              1          1               0        188574.12
# 5686          63K              1          0               1         28640.92
# 2402           0K              2          0               1         10486.69
#
# ...

# %%
type(churn)
# Out:
# pandas.core.frame.DataFrame

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.shape[1]
# Out:
# 14

# %%
churn.shape[0]
# Out:
# 10000

# %%
type(churn.shape)
# Out:
# tuple

# %%
# Try this
# churn.shape[2]

# %%
churn.shape[-1]
# Out:
# 14

# %%
churn.shape[-2]
# Out:
# 10000

# %%
# churn.shape[-3]

# %%
type (churn.shape[1])
# Out:
# int

# %% [markdown]
# #  Row/Column Selection

# %%
churn.Gender == 'Male'
# Out:
# RowNumber
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 9996      True
# 9997      True
# 9998     False
# 9999      True
# 10000    False
# Name: Gender, Length: 10000, dtype: bool

# %%
type(churn.Gender == 'Male')
# Out:
# pandas.core.series.Series

# %%
males =  churn[churn.Gender == 'Male']
males
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
# ...

# %%
male_French_Filter = (churn.Gender == 'Male') & (churn.Geography == 'France')
churn[male_French_Filter]
# Out:
#            CustomerId    Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 7            15592531   Bartlett          822    France   Male   50       7
# 9            15792365         He          501    France   Male   44       4
# 10           15592389         H?          684    France   Male   27       2
# 11           15767821     Bearce          528    France   Male   31       6
# 21           15577657   McDonald          732    France   Male   41       8
# ...               ...        ...          ...       ...    ...  ...     ...
# 9986         15586914     Nepean          659    France   Male   36       6
# 9989         15589329    Pirozzi          775    France   Male   30       4
# 9994         15569266     Rahman          644    France   Male   28       7
# 9996         15606229   Obijiaku          771    France   Male   39       5
# 9997         15569892  Johnstone          516    France   Male   35      10
#
# ...

# %%
type(males)
# Out:
# pandas.core.frame.DataFrame

# %%
males.shape
# Out:
# (5457, 14)

# %%
males.shape[0]
# Out:
# 5457

# %%
males.shape[0]/churn.shape[0]
# Out:
# 0.5457

# %%
churn['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
churn['Gender'].value_counts()[0]
# Out:
# 5457

# %%
churn['Gender'].value_counts()[1]
# Out:
# 4543

# %%
type(churn['Gender'].value_counts())
# Out:
# pandas.core.series.Series

# %%
churn['Gender'].value_counts()/churn.shape[0]
# Out:
# Male      0.5457
# Female    0.4543
# Name: Gender, dtype: float64

# %%
churn['Gender'].value_counts(normalize=True)
# Out:
# Male      0.5457
# Female    0.4543
# Name: Gender, dtype: float64

# %%
churn['Gender'].value_counts()[0]/churn.shape[0]
# Out:
# 0.5457

# %% [markdown]
# ---
#
#
#  ***Select Column from a DataFrame***

# %%
# Select column from DataFrame
males.Surname
# Out:
# RowNumber
# 6               Chu
# 7          Bartlett
# 9                He
# 10               H?
# 11           Bearce
#            ...
# 9993    Chukwualuka
# 9994         Rahman
# 9996       Obijiaku
# 9997      Johnstone
# 9999      Sabbatini
# Name: Surname, Length: 5457, dtype: object

# %%
# Select column from DataFrame
males['Surname']
# Out:
# RowNumber
# 6               Chu
# 7          Bartlett
# 9                He
# 10               H?
# 11           Bearce
#            ...
# 9993    Chukwualuka
# 9994         Rahman
# 9996       Obijiaku
# 9997      Johnstone
# 9999      Sabbatini
# Name: Surname, Length: 5457, dtype: object

# %%
# Select column from DataFrame
males.loc[:,'Surname']
# Out:
# RowNumber
# 6               Chu
# 7          Bartlett
# 9                He
# 10               H?
# 11           Bearce
#            ...
# 9993    Chukwualuka
# 9994         Rahman
# 9996       Obijiaku
# 9997      Johnstone
# 9999      Sabbatini
# Name: Surname, Length: 5457, dtype: object

# %%
males.iloc[:,1]
# Out:
# RowNumber
# 6               Chu
# 7          Bartlett
# 9                He
# 10               H?
# 11           Bearce
#            ...
# 9993    Chukwualuka
# 9994         Rahman
# 9996       Obijiaku
# 9997      Johnstone
# 9999      Sabbatini
# Name: Surname, Length: 5457, dtype: object

# %%
type(males['Surname'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ---
#
#
# ***Select row***

# %%
males.head(10)
# Out:
#            CustomerId   Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012       Chu          645     Spain   Male   44       8
# 7            15592531  Bartlett          822    France   Male   50       7
# 9            15792365        He          501    France   Male   44       4
# 10           15592389        H?          684    France   Male   27       2
# 11           15767821    Bearce          528    France   Male   31       6
# 12           15737173   Andrews          497     Spain   Male   24       3
# 16           15643966   Goforth          616   Germany   Male   45       3
# 17           15737452     Romeo          653   Germany   Male   58       1
# 19           15661507   Muldrow          587     Spain   Male   45       6
# 21           15577657  McDonald          732    France   Male   41       8
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# ...

# %%
males.iloc[6, :]
# Out:
# CustomerId         15643966
# Surname             Goforth
# CreditScore             616
# Geography           Germany
# Gender                 Male
# Age                      45
# Tenure                    3
# Balance                143K
# NumOfProducts             2
# HasCrCard                 0
# IsActiveMember            1
# EstimatedSalary    64327.26
# Exited                    0
# Unnamed: 14             NaN
# Name: 16, dtype: object

# %%
males.loc[6, :]
# Out:
# CustomerId          15574012
# Surname                  Chu
# CreditScore              645
# Geography              Spain
# Gender                  Male
# Age                       44
# Tenure                     8
# Balance                 114K
# NumOfProducts              2
# HasCrCard                  1
# IsActiveMember             0
# EstimatedSalary    149756.71
# Exited                     1
# Unnamed: 14              NaN
# Name: 6, dtype: object

# %%
males.loc[6, 'Surname']
# Out:
# 'Chu'

# %%
males.loc[:, :]
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
# ...

# %%
males.iloc[:, :]
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
# ...

# %%
males.loc[:, :].sample(2)
# Out:
#            CustomerId Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 8873         15626475  Gamble          685    France   Male   30       2
# 5393         15710012   Bowen          738     Spain   Male   44       2
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 8873           0K              2          1               1        140889.32
# 5393           0K              2          1               0         43018.82
#
#            Exited  Unnamed: 14
# RowNumber
# 8873            0          NaN
# 5393            1          NaN

# %%
type(males.iloc[6, :])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Notice that individual Pandas DataFrame columns and rows are type "Series"

# %%
churn[churn.Gender== 'Male']
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
# ...

# %%
churn.groupby(["Geography", "Gender"])["Exited"].count()
# Out:
# Geography  Gender
# France     Female    2261
#            Male      2753
# Germany    Female    1193
#            Male      1316
# Spain      Female    1089
#            Male      1388
# Name: Exited, dtype: int64

# %%
# data_groupby_sex_describe=data.groupby('SEX').describe()

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  object
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
#  13  Unnamed: 14      0 non-null      float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 1.1+ MB

# %%
churn['Age'].isna()
# Out:
# RowNumber
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Name: Age, Length: 10000, dtype: bool

# %%
# churn.count().isnull()
churn['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Remove column with all nulls

# %%
churn['Unnamed: 14'].isna().sum()
# Out:
# 10000

# %%
# all the content of column 13 is NaN (NaN), we can safely delete this column
churn['Unnamed: 14']
# Out:
# RowNumber
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# 10000   NaN
# Name: Unnamed: 14, Length: 10000, dtype: float64

# %%
churn[:5].isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# Unnamed: 14        5
# dtype: int64

# %%
del churn['Unnamed: 14']

# %%
# we now have 13 columns
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  object
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# # selcting rows

# %%
# selecting by rows
churn[1:5]
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
#
#            Exited
# RowNumber
# 2               0
# 3               1
# 4               0
# 5               0

# %%
churn[0:5]
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
#
#            Exited
# ...

# %%
churn[-2:-1]
# Out:
#            CustomerId    Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 9999         15682355  Sabbatini          772   Germany   Male   42       3
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 9999          75K              2          1               0         92888.52
#
#            Exited
# RowNumber
# 9999            1

# %%
churn.head(6)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
# 6            15574012       Chu          645     Spain    Male   44       8
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# ...

# %%
churn.loc[5,'CustomerId']
# Out:
# 15737888

# %%
churn.iloc[4,0]
# Out:
# 15737888

# %%
males.loc[6,'CustomerId']
# Out:
# 15574012

# %%
# churn.loc[0,'CustomerId']

# %%
churn.iloc[4,0]
# Out:
# 15737888

# %%
churn.loc[:,'CustomerId']
# Out:
# RowNumber
# 1        15634602
# 2        15647311
# 3        15619304
# 4        15701354
# 5        15737888
#            ...
# 9996     15606229
# 9997     15569892
# 9998     15584532
# 9999     15682355
# 10000    15628319
# Name: CustomerId, Length: 10000, dtype: int64

# %%
churn.iloc[:,5]
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
churn[:5].isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure  NumOfProducts  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800       1.530200
# std    7.193619e+04     96.653299     10.487806      2.892174       0.581654
# min    1.556570e+07    350.000000     18.000000      0.000000       1.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       1.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000       1.000000
# 75%    1.575323e+07    718.000000     44.000000      7.000000       2.000000
# max    1.581569e+07    850.000000     92.000000     10.000000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %% [markdown]
# ### Validate Existed Percentage

# %%
churn['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
churn['Exited'].value_counts()[1]/churn.shape[0]
# Out:
# 0.2037

# %%
exited_percentage = ((churn.Exited == 1).value_counts(normalize=True))
exited_percentage
# Out:
# False    0.7963
# True     0.2037
# Name: Exited, dtype: float64

# %%
exited_percentage[1]
# Out:
# 0.2037

# %%
# overall correlations
churn.corr()
# Out:
# <ipython-input-189-30d3eb871eed>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   churn.corr()
#                  CustomerId  CreditScore       Age    Tenure  NumOfProducts  \
# CustomerId         1.000000     0.005308  0.009497 -0.014883       0.016972
# CreditScore        0.005308     1.000000 -0.003965  0.000842       0.012238
# Age                0.009497    -0.003965  1.000000 -0.009997      -0.030680
# Tenure            -0.014883     0.000842 -0.009997  1.000000       0.013444
# NumOfProducts      0.016972     0.012238 -0.030680  0.013444       1.000000
# HasCrCard         -0.014025    -0.005458 -0.011721  0.022583       0.003183
# IsActiveMember     0.001665     0.025651  0.085472 -0.028362       0.009612
# EstimatedSalary    0.015271    -0.001384 -0.007201  0.007784       0.014204
# ...

# %%
churn.describe(include=['O'])
# Out:
#        Surname Geography Gender Balance
# count    10000     10000  10000   10000
# unique    2932         3      2     195
# top      Smith    France   Male      0K
# freq        32      5014   5457    3617

# %%
churn.describe(include='all')
# Out:
#           CustomerId Surname   CreditScore Geography Gender           Age  \
# count   1.000000e+04   10000  10000.000000     10000  10000  10000.000000
# unique           NaN    2932           NaN         3      2           NaN
# top              NaN   Smith           NaN    France   Male           NaN
# freq             NaN      32           NaN      5014   5457           NaN
# mean    1.569094e+07     NaN    650.528800       NaN    NaN     38.921800
# std     7.193619e+04     NaN     96.653299       NaN    NaN     10.487806
# min     1.556570e+07     NaN    350.000000       NaN    NaN     18.000000
# 25%     1.562853e+07     NaN    584.000000       NaN    NaN     32.000000
# 50%     1.569074e+07     NaN    652.000000       NaN    NaN     37.000000
# 75%     1.575323e+07     NaN    718.000000       NaN    NaN     44.000000
# max     1.581569e+07     NaN    850.000000       NaN    NaN     92.000000
#
#               Tenure Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Cleanup Balance Column

# %%
churn['Balance'] =  churn["Balance"].str.replace('K','').astype('int')
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
# churn.loc[:,'Balance'] = churn['Balance'].str.replace("K", '').astype(int)
# churn.sample(2)

# %%
# churn['Balance'] = churn['Balance'].str.replace('K',' ')
# churn['Balance'] = churn['Balance'].astype('int64')

# %%
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
churn.describe(include='all')
# Out:
#           CustomerId Surname   CreditScore Geography Gender           Age  \
# count   1.000000e+04   10000  10000.000000     10000  10000  10000.000000
# unique           NaN    2932           NaN         3      2           NaN
# top              NaN   Smith           NaN    France   Male           NaN
# freq             NaN      32           NaN      5014   5457           NaN
# mean    1.569094e+07     NaN    650.528800       NaN    NaN     38.921800
# std     7.193619e+04     NaN     96.653299       NaN    NaN     10.487806
# min     1.556570e+07     NaN    350.000000       NaN    NaN     18.000000
# 25%     1.562853e+07     NaN    584.000000       NaN    NaN     32.000000
# 50%     1.569074e+07     NaN    652.000000       NaN    NaN     37.000000
# 75%     1.575323e+07     NaN    718.000000       NaN    NaN     44.000000
# max     1.581569e+07     NaN    850.000000       NaN    NaN     92.000000
#
#               Tenure       Balance  NumOfProducts    HasCrCard  \
# ...

# %%
g1 = churn.groupby(['Gender']).size(); g1
# Out:
# Gender
# Female    4543
# Male      5457
# dtype: int64

# %%
churn['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
churn['Gender'].value_counts(normalize=True)
# Out:
# Male      0.5457
# Female    0.4543
# Name: Gender, dtype: float64

# %%
g1 = churn.groupby(['Geography']).size(); g1
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# dtype: int64

# %%
churn['Geography'].value_counts(normalize=True)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %% [markdown]
# # Additional EDA

# %%
churn['Age']
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
churn.Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
type(churn.Age)
# Out:
# pandas.core.series.Series

# %%
churn[['Age']]
# Out:
#            Age
# RowNumber
# 1           42
# 2           41
# 3           42
# 4           39
# 5           43
# ...        ...
# 9996        39
# 9997        35
# 9998        36
# 9999        42
# 10000       28
#
# [10000 rows x 1 columns]

# %%
type(churn['Age'])
# Out:
# pandas.core.series.Series

# %%
type(churn[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
Age = churn['Age']
Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
Age = churn.Age
Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
type(Age)
# Out:
# pandas.core.series.Series

# %%
churn['Age'].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
churn['Age'].describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
churn['Age'].describe()[1]
# Out:
# 38.9218

# %%
churn['Age'].describe()[-1]
# Out:
# 92.0

# %%
churn['Age'].mean()
# Out:
# 38.9218

# %%
churn['Exited'].value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %% [markdown]
# # Change column order

# %%
churn.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
col_names = churn.columns[::-1]
col_names
# Out:
# Index(['Exited', 'EstimatedSalary', 'IsActiveMember', 'HasCrCard',
#        'NumOfProducts', 'Balance', 'Tenure', 'Age', 'Gender', 'Geography',
#        'CreditScore', 'Surname', 'CustomerId'],
#       dtype='object')

# %%
newColOrder = ['CustomerId', 'Geography','Surname', 'CreditScore', 'Gender', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Exited']
churn = churn[newColOrder]
churn
# Out:
#            CustomerId Geography    Surname  CreditScore  Gender  Age  Tenure  \
# RowNumber
# 1            15634602    France   Hargrave          619  Female   42       2
# 2            15647311     Spain       Hill          608  Female   41       1
# 3            15619304    France       Onio          502  Female   42       8
# 4            15701354    France       Boni          699  Female   39       1
# 5            15737888     Spain   Mitchell          850  Female   43       2
# ...               ...       ...        ...          ...     ...  ...     ...
# 9996         15606229    France   Obijiaku          771    Male   39       5
# 9997         15569892    France  Johnstone          516    Male   35      10
# 9998         15584532    France        Liu          709  Female   36       7
# 9999         15682355   Germany  Sabbatini          772    Male   42       3
# 10000        15628319    France     Walker          792  Female   28       4
#
# ...

# %% [markdown]
# # change the index

# %%
print (churn.CustomerId.count())
print (churn.CustomerId.nunique())
# Out:
# 10000
# 10000

# %%
# churn = churn.set_index('CustomerId')
# churn

# %%
churn.set_index('CustomerId', inplace=True)
churn
# Out:
#            Geography    Surname  CreditScore  Gender  Age  Tenure  Balance  \
# CustomerId
# 15634602      France   Hargrave          619  Female   42       2        0
# 15647311       Spain       Hill          608  Female   41       1       84
# 15619304      France       Onio          502  Female   42       8      160
# 15701354      France       Boni          699  Female   39       1        0
# 15737888       Spain   Mitchell          850  Female   43       2      126
# ...              ...        ...          ...     ...  ...     ...      ...
# 15606229      France   Obijiaku          771    Male   39       5        0
# 15569892      France  Johnstone          516    Male   35      10       57
# 15584532      France        Liu          709  Female   36       7        0
# 15682355     Germany  Sabbatini          772    Male   42       3       75
# 15628319      France     Walker          792  Female   28       4      130
#
# ...

# %%
churn.shape
# Out:
# (10000, 12)

# %% [markdown]
# ### Cleanup Balance Column

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geography        10000 non-null  object
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  int64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 1015.6+ KB

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geography        10000 non-null  object
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  int64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 1015.6+ KB

# %% [markdown]
# ### Change column data type (Type Casting)

# %%
churn['Geography'] = churn['Geography'].astype('category')
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geography        10000 non-null  category
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  int64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: category(1), float64(1), int64(8), object(2)
# memory usage: 947.4+ KB
