# %%
import pandas as pd

# %%
dataset = pd.read_csv('Churn-Modelling.csv')
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
filteredData = dataset[dataset['Gender'] == 'Male']
filteredData.shape
# Out:
# (5457, 15)

# %%
filteredData = dataset.query(("Gender == 'Male' and Age > 40"))
filteredData
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012        Chu          645     Spain   Male   44
# 6             7    15592531   Bartlett          822    France   Male   50
# 8             9    15792365         He          501    France   Male   44
# 15           16    15643966    Goforth          616   Germany   Male   45
# 16           17    15737452      Romeo          653   Germany   Male   58
# ...         ...         ...        ...          ...       ...    ...  ...
# 9970       9971    15587133   Thompson          518    France   Male   42
# 9975       9976    15666295      Smith          610   Germany   Male   50
# 9981       9982    15672754   Burbidge          498   Germany   Male   42
# 9986       9987    15581736   Bartlett          673   Germany   Male   47
# 9998       9999    15682355  Sabbatini          772   Germany   Male   42
#
#       Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
categorical_features = ['A', 'B', 'C', 'D']
## chage the list to dataframe
df = pd.DataFrame(categorical_features, columns=['features'], index=['A', 'B', 'C', 'D'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['features'] = le.fit_transform(df['features'])
df
# Out:
#    features
# A         0
# B         1
# C         2
# D         3

# %%
# from sklearn.preprocessing import OneHotEncoder
# ohe = pd.get_dummies(df['features'], prefix='feature')
# df.drop(['features'], axis=1, inplace=True)
# df = pd.concat([df, ohe], axis=1)

from sklearn.preprocessing import OneHotEncoder
ohe = pd.get_dummies(df, columns=['features'], prefix='feature')
ohe
# Out:
#    feature_0  feature_1  feature_2  feature_3
# A          1          0          0          0
# B          0          1          0          0
# C          0          0          1          0
# D          0          0          0          1

# %%
dataset.iloc[4:6, 1:6]
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender
# 4    15737888  Mitchell          850     Spain  Female
# 5    15574012       Chu          645     Spain    Male

# %%
dataset.iloc[:, 1:6].sample(10)
# Out:
#       CustomerId   Surname  CreditScore Geography  Gender
# 1247    15711288       Hay          512    France    Male
# 1911    15590606  Saunders          595    France    Male
# 8824    15752388     Doyle          643     Spain  Female
# 556     15705515   Lazarev          587   Germany    Male
# 7040    15655658  Bulgakov          678    France  Female
# 2828    15716449    Fraser          527     Spain    Male
# 9588    15744914     Moore          539   Germany    Male
# 7150    15691150        Ku          699    France  Female
# 8305    15605698  Harrison          746    France    Male
# 3179    15685536       Chu          552    France  Female

# %%
dataset.iloc[:,:].isna().sum()
# Out:
# RowNumber              0
# CustomerId             0
# Surname                0
# CreditScore            0
# Geography              0
# Gender                 0
# Age                    0
# Tenure                 0
# Balance                0
# NumOfProducts          0
# HasCrCard              0
# IsActiveMember         0
# EstimatedSalary        0
# Exited                 0
# Unnamed: 14        10000
# dtype: int64

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
dataset.loc[:, 'Exited'].value_counts()/dataset.shape[0]
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
exited_percentage = ((dataset.Exited == 1).value_counts(normalize=True)*100).round(2)
exited_percentage
# Out:
# False    79.63
# True     20.37
# Name: Exited, dtype: float64

# %%
dataset.corr()
# Out:
# C:\Users\fahad\AppData\Local\Temp\ipykernel_3420\2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# ...

# %%
dataset.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure Balance  NumOfProducts    HasCrCard  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  object
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  Unnamed: 14      0 non-null      float64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 1.1+ MB

# %%
dataset['Balance'] = dataset['Balance'].str.replace('K','').astype('float64')
object_columns = dataset.select_dtypes(include='object').columns

# %%
object_columns.drop('Surname')
# Out:
# Index(['Geography', 'Gender'], dtype='object')

# %%
dataset.set_index('RowNumber', inplace=True)
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#            Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0.0              1          1               1        101348.88
# 2             84.0              1          0               1        112542.58
# 3            160.0              3          1               0        113931.57
# 4              0.0              2          0               0         93826.63
# 5            126.0              1          1               1         79084.10
#
# ...

# %%
dataset.describe(include='all')
# Out:
#           CustomerId Surname   CreditScore Geography Gender           Age  \
# count   1.000000e+04   10000  10000.000000     10000  10000  10000.000000
# unique           NaN    2932           NaN         3      2           NaN
# top              NaN   Smith           NaN    France   Male           NaN
# freq             NaN      32           NaN      5014   5457           NaN
# mean    1.569094e+07     NaN    650.528800       NaN    NaN     38.921800
# std     7.193619e+04     NaN     96.653299       NaN    NaN     10.487806
# min     1.556570e+07     NaN    350.000000       NaN    NaN     18.000000
# 25%     1.562853e+07     NaN    584.000000       NaN    NaN     32.000000
# 50%     1.569074e+07     NaN    652.000000       NaN    NaN     37.000000
# 75%     1.575323e+07     NaN    718.000000       NaN    NaN     44.000000
# max     1.581569e+07     NaN    850.000000       NaN    NaN     92.000000
#
#               Tenure       Balance  NumOfProducts    HasCrCard  \
# ...

# %%
g1 = dataset.groupby('Gender').size() ; g1
# Out:
# Gender
# Female    4543
# Male      5457
# dtype: int64

# %%
dataset['Gender'].value_counts(normalize=True)*100
# Out:
# Male      54.57
# Female    45.43
# Name: Gender, dtype: float64

# %%
g1 = dataset.groupby('Geography').size() ; g1
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# dtype: int64

# %%
dataset['Geography'].value_counts(normalize=True)*100
# Out:
# France     50.14
# Germany    25.09
# Spain      24.77
# Name: Geography, dtype: float64

# %%
type(dataset.Age)
# Out:
# pandas.core.series.Series

# %%
type(dataset['Age'])
# Out:
# pandas.core.series.Series

# %%
type(dataset[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
dataset[['Age']].describe()
# Out:
#                 Age
# count  10000.000000
# mean      38.921800
# std       10.487806
# min       18.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max       92.000000

# %%
dataset['Age'].describe()[:]
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
dataset['Age'].mean()
# Out:
# 38.9218

# %%
dataset['Exited'].value_counts(normalize=True)*100
# Out:
# 0    79.63
# 1    20.37
# Name: Exited, dtype: float64

# %%
dataset.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Unnamed: 14'],
#       dtype='object')

# %%
dataset_colnames = dataset.columns[::-1]; dataset_colnames
# Out:
# Index(['Unnamed: 14', 'Exited', 'EstimatedSalary', 'IsActiveMember',
#        'HasCrCard', 'NumOfProducts', 'Balance', 'Tenure', 'Age', 'Gender',
#        'Geography', 'CreditScore', 'Surname', 'CustomerId'],
#       dtype='object')

# %%
new_order = ['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Exited']

# %%
dataset = dataset[new_order]

# %%
dataset
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
objecttypes = dataset.select_dtypes(include=['object'])
objecttypes = objecttypes.drop(['Surname'], axis=1)
objecttypes
gtenderBYLocation = objecttypes.groupby('Geography').value_counts(normalize=True)*100
gtenderBYLocationDF = pd.DataFrame(gtenderBYLocation)
type(gtenderBYLocationDF)
gtenderBYLocationDF.columns = ['Percentage']
gtenderBYLocationDF
# Out:
#                   Percentage
# Geography Gender
# France    Male     54.906262
#           Female   45.093738
# Germany   Male     52.451176
#           Female   47.548824
# Spain     Male     56.035527
#           Female   43.964473

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
dataset[['Geography', 'Gender']] = dataset[['Geography', 'Gender']].astype('category')
# Out:
# C:\Users\fahad\AppData\Local\Temp\ipykernel_3420\2097733833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[['Geography', 'Gender']] = dataset[['Geography', 'Gender']].astype('category')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  category
#  4   Gender           10000 non-null  category
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: category(2), float64(2), int64(8), object(1)
# memory usage: 957.3+ KB

# %%
dataset['Age'].isna().sum()
dataset[:5].isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
dataset.shape
# Out:
# (10000, 13)

# %%
dataset['Exited'].value_counts(normalize=True)*100
# Out:
# 0    79.63
# 1    20.37
# Name: Exited, dtype: float64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  category
#  4   Gender           10000 non-null  category
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: category(2), float64(2), int64(8), object(1)
# memory usage: 957.3+ KB

# %%
numeric_data = dataset.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
numeric_data  = ['CreditScore',
 'Age',
 'Tenure',
 'Balance',
 'NumOfProducts',
 'EstimatedSalary'
]

# %%
numeric_data
# Out:
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# %%
categorialdata = dataset.select_dtypes(include=['category']).columns.tolist()

# %%
categorialdata
# Out:
# ['Geography', 'Gender']

# %%
target = ['Exited']

# %%
binary_data = [ 'HasCrCard',
 'IsActiveMember']

# %%
dataset[target]
# Out:
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0
# ...           ...
# 9996            0
# 9997            0
# 9998            1
# 9999            1
# 10000           0
#
# [10000 rows x 1 columns]

# %%
X = dataset[numeric_data + categorialdata + binary_data]

# %%
X
# Out:
#            CreditScore  Age  Tenure  Balance  NumOfProducts  EstimatedSalary  \
# RowNumber
# 1                  619   42       2      0.0              1        101348.88
# 2                  608   41       1     84.0              1        112542.58
# 3                  502   42       8    160.0              3        113931.57
# 4                  699   39       1      0.0              2         93826.63
# 5                  850   43       2    126.0              1         79084.10
# ...                ...  ...     ...      ...            ...              ...
# 9996               771   39       5      0.0              2         96270.64
# 9997               516   35      10     57.0              1        101699.77
# 9998               709   36       7      0.0              1         42085.58
# 9999               772   42       3     75.0              2         92888.52
# 10000              792   28       4    130.0              1         38190.78
#
# ...

# %%
y = dataset[target]

# %%
y
# Out:
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0
# ...           ...
# 9996            0
# 9997            0
# 9998            1
# 9999            1
# 10000           0
#
# [10000 rows x 1 columns]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='median'), numeric_data),
        ('cat', OneHotEncoder(), categorialdata)]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', SimpleImputer(strategy='median'),
#                                  ['CreditScore', 'Age', 'Tenure', 'Balance',
#                                   'NumOfProducts', 'EstimatedSalary']),
#                                 ('cat', OneHotEncoder(),
#                                  ['Geography', 'Gender'])])

# %%
type(preprocessor)
# Out:
# sklearn.compose._column_transformer.ColumnTransformer

# %%
X
# Out:
#            CreditScore  Age  Tenure  Balance  NumOfProducts  EstimatedSalary  \
# RowNumber
# 1                  619   42       2      0.0              1        101348.88
# 2                  608   41       1     84.0              1        112542.58
# 3                  502   42       8    160.0              3        113931.57
# 4                  699   39       1      0.0              2         93826.63
# 5                  850   43       2    126.0              1         79084.10
# ...                ...  ...     ...      ...            ...              ...
# 9996               771   39       5      0.0              2         96270.64
# 9997               516   35      10     57.0              1        101699.77
# 9998               709   36       7      0.0              1         42085.58
# 9999               772   42       3     75.0              2         92888.52
# 10000              792   28       4    130.0              1         38190.78
#
# ...

# %%
X = preprocessor.fit_transform(X)

# %%
X
# Out:
# array([[619.,  42.,   2., ...,   0.,   1.,   0.],
#        [608.,  41.,   1., ...,   1.,   1.,   0.],
#        [502.,  42.,   8., ...,   0.,   1.,   0.],
#        ...,
#        [709.,  36.,   7., ...,   0.,   1.,   0.],
#        [772.,  42.,   3., ...,   0.,   0.,   1.],
#        [792.,  28.,   4., ...,   0.,   1.,   0.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=43)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_cl = DecisionTreeClassifier(random_state=42)

# %%
dt_cl.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
y_test_pred = dt_cl.predict(X_test)
print(f'Area Under the ROC Curve: {roc_auc_score(y_test, y_test_pred): 0.4f}')
print(f'Accuracy: {accuracy_score(y_test, y_test_pred): 0.4f}')
print(f'F1 Score: {f1_score(y_test, y_test_pred): 0.4f}')
print(classification_report(y_test, y_test_pred, digits=4))
pd.DataFrame(confusion_matrix(y_test, y_test_pred))
# Out:
# Area Under the ROC Curve:  0.6707
# Accuracy:  0.7825
# F1 Score:  0.4765
#               precision    recall  f1-score   support
#
#            0     0.8646    0.8608    0.8627      1588
#            1     0.4726    0.4806    0.4765       412
#
#     accuracy                         0.7825      2000
#    macro avg     0.6686    0.6707    0.6696      2000
# weighted avg     0.7839    0.7825    0.7832      2000
#       0    1
# 0  1367  221
# 1   214  198

# %%
from sklearn.model_selection import GridSearchCV
clf_df = DecisionTreeClassifier(class_weight='balanced', random_state=42)
param_grid_dt = {'criterion': ['gini', 'entropy'],
                 'max_depth': list(range(4, 250))}
grid_dt = GridSearchCV(clf_df, param_grid_dt, cv=5, scoring='roc_auc', n_jobs=-1, verbose=20)
grid_dt.fit(X_train, y_train)

print(f'Best Score: {grid_dt.best_score_}')
print(f'Best Parameters: {grid_dt.best_params_}')
print(f'Best Estimator: {grid_dt.best_estimator_}')
# Out:
# Fitting 5 folds for each of 492 candidates, totalling 2460 fits
# Best Score: 0.8334745098039216
# Best Parameters: {'criterion': 'entropy', 'max_depth': 6}
# Best Estimator: DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, random_state=42)

# %%
y_test_pred = grid_dt.predict(X_test)
print(f'Area Under the ROC Curve: {roc_auc_score(y_test, y_test_pred): 0.4f}')
print(f'Accuracy: {accuracy_score(y_test, y_test_pred): 0.4f}')
print(f'F1 Score: {f1_score(y_test, y_test_pred): 0.4f}')
print(classification_report(y_test, y_test_pred, digits=4))
pd.DataFrame(confusion_matrix(y_test, y_test_pred))
# Out:
# Area Under the ROC Curve:  0.7617
# Accuracy:  0.7515
# F1 Score:  0.5637
#               precision    recall  f1-score   support
#
#            0     0.9285    0.7443    0.8263      1588
#            1     0.4415    0.7791    0.5637       412
#
#     accuracy                         0.7515      2000
#    macro avg     0.6850    0.7617    0.6950      2000
# weighted avg     0.8282    0.7515    0.7722      2000
#       0    1
# 0  1182  406
# 1    91  321
